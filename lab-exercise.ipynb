# %%
import pandas as pd

# %% [markdown]
# # Exercise1

# %%
df1 = pd.read_csv("files_for_lab/csv_files/file1.csv")
df2 = pd.read_csv("files_for_lab/csv_files/file2.csv")
df3 = pd.read_csv("files_for_lab/csv_files/file3.csv")

# %%
df1.head(2)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
# 1  QZ44356     Arizona      F  Bachelor              697953.59%     0.0
#
#    Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0                1000.0                    1/0/00  Personal Auto
# 1                  94.0                    1/0/00  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935

# %%
df2.head(2)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
#
#      Policy Type  Vehicle Class
# 0  Personal Auto  Four-Door Car
# 1   Special Auto            SUV

# %%
df3.head(2)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
#
#    Total Claim Amount Vehicle Class
# 0          499.200000  Two-Door Car
# 1            3.468912  Two-Door Car

# %% [markdown]
# # Exercise2

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %% [markdown]
# # Exercise3

# %%
df1.columns = df1.columns.str.lower()
df2.columns = df2.columns.str.lower()
df3.columns = df3.columns.str.lower()

# %% [markdown]
# # Exercise4

# %%
df1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
df2.reindex(columns=df1.columns)
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
df3.rename(columns = {'state' : 'st'}, inplace = True) #before reindexing we have to change the columns title to match df1 and df2.
df3
# Out:
#      customer          st  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
df3.reindex(columns=df1.columns)
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %% [markdown]
# # Exercise5

# %%
df_all = pd.concat([df1, df2, df3], ignore_index=True)
df_all
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# # Exercise6

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numerics_df = df_all.select_dtypes(include=numerics)
numerics_df.columns
# Out:
# Index(['income', 'monthly premium auto', 'total claim amount'], dtype='object')

# %% [markdown]
# # Exercise7

# %%
non_numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

non_numerics_df = df_all.select_dtypes(exclude=numerics)
non_numerics_df.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'number of open complaints', 'policy type', 'vehicle class'],
#       dtype='object')

# %% [markdown]
# # Exercise8

# %% [markdown]
# Ok, I understand

# %% [markdown]
# # Exercise9

# %%
df_all.drop(['education', 'number of open complaints'], axis=1, inplace=True)
df_all
# Out:
#       customer          st gender customer lifetime value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
def multiply(x):
    return x*2

df_all['customer lifetime value'] = df_all['customer lifetime value'].astype(str)
df_all
#df_all['customer lifetime value %'] = df_all['customer lifetime value'].apply(multiply)
#df_all
# Out:
#       customer          st gender customer lifetime value   income  \
# 0      RB50392  Washington    NaN                     nan      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
duplicates = df_all.duplicated(keep='first')

# %%
df_all[~duplicates]
# Out:
#       customer          st gender customer lifetime value   income  \
# 0      RB50392  Washington    NaN                     nan      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
mask = df_all["income"] == 0.0
df_all[~mask]
# Out:
#       customer          st gender customer lifetime value   income  \
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# 5      OC83172      Oregon      F              825629.78%  62902.0
# 6      XZ87318      Oregon      F              538089.86%  55350.0
# 8      DY87989      Oregon      M             2412750.40%  14072.0
# ...        ...         ...    ...                     ...      ...
# 12067  TF56202  California      M             5032.165498  66367.0
# 12068  YM19146  California      F             4100.398533  47761.0
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12072  UP19263  California      M             7524.442436  21941.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 2                     108.0   Personal Auto   Two-Door Car          566.472247
# ...
